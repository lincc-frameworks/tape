# %% [markdown]
# # PLAsTiCC data exploration with TAPE
#
# Let's explore [PLAsTiCC](http://plasticc.org) data!
#
# It is publically avilable through [this Zenodo repository](https://zenodo.org/record/2539456).

# %%
## Uncomment to install packages

# !pip install tape joblib requests pyarrow.csv pyarrow

# %% [markdown]
# ### Download the data
#
# Please get the data from [Zenodo](https://zenodo.org/record/2539456) and put them to the `./plasticc` folder (you may change the location bellow with `DATA_DIR`).

# %%
from pathlib import Path

DATA_DIR = Path("../../../../../datasets/plasticc")

META_FILENAME = "plasticc_test_metadata.csv"
LC_FILENAMES = [f"plasticc_test_lightcurves_{i:02d}.csv" for i in range(1, 12)]
# META_FILENAME = "plasticc_train_metadata.csv.gz"
# LC_FILENAMES = ['plasticc_train_lightcurves.csv.gz']

N_PARTITIONS = len(LC_FILENAMES)

N_PROCESSORS = 4

# %% [markdown]
# You may skip the next cell if you already have the data downloaded in the `DATA_DIR`.

# %% [markdown]
# # Read and analyse the data with TAPE

# %% [markdown]
# Initial loading of the ensemble

# %%
# %%time

import light_curve as licu
import dask.dataframe as dd
import numpy as np
from tape import Ensemble, ColumnMapper

# In TAPE's (and LSST's) terminology, sources are individual detections,
# and objects are the underlying astrophysical objects.

# We load object table first, from the metadata file.
print("Loading object table...")
object_table = dd.read_csv(
    DATA_DIR / META_FILENAME,
    # Read data chunk by chunk, to avoid loading the whole file into memory.
    blocksize=100e6,
)

# Then we load the sources:
print("Loading source tables...")
source_table = dd.read_csv(
    [DATA_DIR / filename for filename in LC_FILENAMES],
    blocksize=100e6,
)

# Now we can make an Ensemble.
# To make parallel processing work we need to partition the data.
# After that, when we run analysis, TAPE will distribute the work:
# one partition per worker.
print("Building Ensemble...")
ens = Ensemble(
    n_workers=N_PROCESSORS,
)
ens.from_dask_dataframe(
    source_frame=source_table,
    object_frame=object_table,
    npartitions=None,
    column_mapper=ColumnMapper(
        id_col='object_id',
        time_col='mjd',
        flux_col='flux',
        err_col='flux_err',
        band_col='passband',
    ),
    # TODO: Doug, please put a comment here about the following line.
    sync_tables=False,
)
# Out:
# Loading object table...
# Loading source tables...
# Building Ensemble...
# /Users/wilsonbb/Dropbox/lincc/tape/big_merge/tape/.conda/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 65174 instead
#   warnings.warn(
# Beginning setting index for frame: source
# set_dirty called for frame: source with value: False
# set_dirty called for frame: source with value: False
# Ending setting index for frame: source
# set_dirty called for frame: source with value: False
# Updating frame: source (is frame dirty: False)
# Updating frame: object (is frame dirty: False)
# Beginning setting index for frame: object
# Ending setting index for frame: object
# set_dirty called for frame: object with value: False
# Updating frame: object (is frame dirty: False)
# CPU times: user 5.85 s, sys: 1.58 s, total: 7.43 s
# Wall time: 42.2 s

# %% [markdown]
# Run the query, this should be lazy and *NOT* trigger _sync_tables

# %%
# %%time
# Let's run some analysis!

print("Starting analysis...")
# First, let's select only Galactic objects, by cutting on hostgal_photoz.
print("First, filter by photoz")
ens = ens.query("hostgal_photoz < 1e-3", table="object")
# Out:
# Starting analysis...
# First, filter by photoz
# Beginning query for frame: object
# Ending query for frame: object
# set_dirty called for frame: object with value: False
# Setting frame object as dirty
# set_dirty called for frame: object with value: True
# Updating frame: object (is frame dirty: True)
# CPU times: user 105 ms, sys: 27.9 ms, total: 133 ms
# Wall time: 2.1 s

# %% [markdown]
# Run the first batch call. Here we should trigger the table sync

# %%
# %%time
# Second, let's select persistent sources, by cutting on the duration of the light curve.
print("Extract durations")
duration = ens.batch(
    lambda time, detected: np.ptp(time[np.asarray(detected, dtype=bool)]),
    ens._time_col, 'detected_bool',
    meta=('duration', 'float64'),
    use_map=False,
    compute=False,
)
# Out:
# Extract durations
# _sync_tables started
# Syncing source table is started
# Syncing source table, index computed
# Setting frame source as dirty
# set_dirty called for frame: source with value: True
# Updating frame: source (is frame dirty: True)
# Syncing source table, partitions mapped
# Beginning persist for frame: source
# Ending persist for frame: source
# set_dirty called for frame: source with value: True
# 2023-10-25 09:19:07,119 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 5.65 GiB -- Worker memory limit: 8.00 GiB
# Updating frame: source (is frame dirty: True)
# Syncing source table, frame persisted
# Syncing object table started
# Syncing object table index computed
# Updating frame: object (is frame dirty: False)
# Syncing object table partitions mapped
# Beginning persist for frame: object
# Ending persist for frame: object
# set_dirty called for frame: object with value: False
# Updating frame: object (is frame dirty: False)
# Syncing object table, frame persisted
# _sync_tables finished
# set_dirty called for frame: source with value: False
# set_dirty called for frame: object with value: False
# CPU times: user 18.4 s, sys: 6.72 s, total: 25.1 s
# Wall time: 4min 57s

# %% [markdown]
# Finish the rest of the workflow. One issue for optimization is if we are triggering unnecessary syncs

# %%
# %%time

print("Assign a column")
ens.assign(table="object", duration=duration)
print("Filter by duration")
ens = ens.query("duration > 366", table="object")

# Next, we use Otsu's method to split light curves into two groups:
# one with high flux, and one with low flux. Eclipsing binaries should have
# lower flux group smaller than the higher flux group, but having larger 
# variability. We use light-curve package to extract these features.
# (https://github.com/light-curve/light-curve-python)
# For simplicity, we only calculate these features for the i (3) band.
print("Extract Otsu features")
otsu_features = ens.batch(licu.OtsuSplit(), band_to_calc=3, use_map=False, compute=False)
print("Assign columns")
ens = ens.assign(
    table="object",
    otsu_lower_to_all_ratio=otsu_features['otsu_lower_to_all_ratio'],
    otsu_std_lower=otsu_features['otsu_std_lower'],
    otsu_std_upper=otsu_features['otsu_std_upper'],
)
print('Filter by Otsu features')
ens = ens.query(
    "otsu_lower_to_all_ratio < 0.1 and otsu_std_lower > otsu_std_upper",
    table="object",
)
print("Compute object table")
ens.compute("object")
# Out:
# Assign a column
# set_dirty called for frame: object with value: False
# set_dirty called for frame: object with value: False
# Updating frame: object (is frame dirty: False)
# set_dirty called for frame: object with value: True
# Filter by duration
# Beginning query for frame: object
# Ending query for frame: object
# set_dirty called for frame: object with value: True
# Setting frame object as dirty
# set_dirty called for frame: object with value: True
# Updating frame: object (is frame dirty: True)
# Extract Otsu features
# _sync_tables started
# Syncing source table is started
# Syncing source table, index computed
# Setting frame source as dirty
# set_dirty called for frame: source with value: True
# Updating frame: source (is frame dirty: True)
# Syncing source table, partitions mapped
# Beginning persist for frame: source
# Ending persist for frame: source
# set_dirty called for frame: source with value: True
# Updating frame: source (is frame dirty: True)
# Syncing source table, frame persisted
# Syncing object table started
# Syncing object table index computed
# Updating frame: object (is frame dirty: False)
# Syncing object table partitions mapped
# Beginning persist for frame: object
# Ending persist for frame: object
# set_dirty called for frame: object with value: False
# Updating frame: object (is frame dirty: False)
# Syncing object table, frame persisted
# _sync_tables finished
# set_dirty called for frame: source with value: False
# set_dirty called for frame: object with value: False
# Assign columns
# set_dirty called for frame: object with value: False
# set_dirty called for frame: object with value: False
# Updating frame: object (is frame dirty: False)
# set_dirty called for frame: object with value: True
# Filter by Otsu features
# Beginning query for frame: object
# Ending query for frame: object
# set_dirty called for frame: object with value: True
# 2023-10-25 09:22:11,054 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:12,021 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:12,949 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:13,948 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:14,839 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:15,635 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:16,627 - distributed.utils_perf - WARNING - full garbage collections took 22% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:17,583 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:18,456 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:19,348 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:20,157 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:21,158 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:22,129 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:23,072 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:23,952 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:24,844 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:25,670 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:26,457 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:27,396 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:28,277 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:29,040 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:29,245 - distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# Setting frame object as dirty
# set_dirty called for frame: object with value: True
# Updating frame: object (is frame dirty: True)
# Compute object table
# 2023-10-25 09:22:30,659 - distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:30,757 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:31,558 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:31,688 - distributed.utils_perf - WARNING - full garbage collections took 36% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:32,422 - distributed.utils_perf - WARNING - full garbage collections took 26% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:32,543 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:33,380 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:33,429 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:34,249 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:34,281 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:35,226 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:35,264 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:36,045 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:36,214 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:37,014 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:37,137 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:37,948 - distributed.utils_perf - WARNING - full garbage collections took 35% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:37,987 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:38,910 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:38,959 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:39,693 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:39,891 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:40,717 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:40,947 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:41,732 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:41,899 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:42,602 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:42,834 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:43,545 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:43,770 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:44,545 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:44,731 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:45,523 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:45,673 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:46,373 - distributed.utils_perf - WARNING - full garbage collections took 33% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:46,521 - distributed.utils_perf - WARNING - full garbage collections took 29% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:47,186 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:47,523 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:48,180 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:48,711 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:49,175 - distributed.utils_perf - WARNING - full garbage collections took 34% CPU time recently (threshold: 10%)
# 2023-10-25 09:22:49,655 - distributed.utils_perf - WARNING - full garbage collections took 28% CPU time recently (threshold: 10%)
#                  ra     decl  ddf_bool  hostgal_specz  hostgal_photoz  \
# object_id
# 1040934    192.1674 -46.3751         0           -9.0             0.0
# 1145188    104.4141 -12.1773         0           -9.0             0.0
# 1184639    326.9531 -22.8314         0           -9.0             0.0
# 1226593     48.5156 -32.2662         0           -9.0             0.0
# 1227515    183.3398 -16.9578         0           -9.0             0.0
# ...             ...      ...       ...            ...             ...
# 130633244  152.9297 -12.4828         0           -9.0             0.0
# 130634660   36.8182 -46.7685         0           -9.0             0.0
# 130708654   95.0977 -36.0536         0           -9.0             0.0
# 130711141  133.0349 -47.1613         0           -9.0             0.0
# 130760691   41.0377 -60.6234         0           -9.0             0.0
#
#            hostgal_photoz_err  distmod  mwebv  target  true_target  ...  \
# object_id                                                           ...
# 1040934                   0.0     -9.0  0.083       0           65  ...
# 1145188                   0.0     -9.0  0.625       0           16  ...
# 1184639                   0.0     -9.0  0.032       0           16  ...
# 1226593                   0.0     -9.0  0.014       0           65  ...
# 1227515                   0.0     -9.0  0.049       0           16  ...
# ...                       ...      ...    ...     ...          ...  ...
# 130633244                 0.0     -9.0  0.058       0           16  ...
# 130634660                 0.0     -9.0  0.014       0           16  ...
# 130708654                 0.0     -9.0  0.052       0           16  ...
# 130711141                 0.0     -9.0  1.271       0           16  ...
# 130760691                 0.0     -9.0  0.019       0           16  ...
#
#            tflux_u  tflux_g  tflux_r  tflux_i  tflux_z  tflux_y   duration  \
# object_id
# 1040934        5.7     33.7    110.5    539.1   1183.9   1991.1   410.0927
# 1145188      341.5   3106.7   3207.9   2379.2   1631.3    717.8  1073.9476
# 1184639     2114.8  19954.1  20819.5  15006.2   9573.4   3997.2   728.8966
# 1226593       15.0     25.1     43.4    140.4    285.6    467.0   830.8233
# 1227515      733.2  11232.6  16446.4  14553.2  10543.4   4789.5  1056.0646
# ...            ...      ...      ...      ...      ...      ...        ...
# 130633244    232.1   1957.9   1864.3   1267.8    781.9    319.2  1086.8704
# 130634660     51.2    379.4    331.9    214.8    128.2     51.3   839.7401
# 130708654   2059.7  20970.8  23290.0  17505.6  11486.4   4893.3  1008.0936
# 130711141    489.5   6468.5   7909.4   6421.0   4922.0   2323.3  1025.3035
# 130760691   2253.9  20228.1  20220.5  14140.9   8841.9   3641.2   618.1205
#
#            otsu_lower_to_all_ratio  otsu_std_lower  otsu_std_upper
# object_id
# 1040934                   0.090909       10.038970        7.000799
# 1145188                   0.090909      111.621817       67.960107
# 1184639                   0.086957      563.869493       25.370866
# 1226593                   0.080000       12.008922        4.690816
# 1227515                   0.095238      765.642029      122.818703
# ...                            ...             ...             ...
# 130633244                 0.080000       57.311277       12.255049
# 130634660                 0.080000        8.145193        7.080347
# 130708654                 0.095238     1425.256064      480.315334
# 130711141                 0.095238      139.958460      136.504984
# 130760691                 0.095238      324.107728       39.129642
#
# [4354 rows x 29 columns]
# 2023-10-25 09:23:15,674 - distributed.nanny - WARNING - Restarting worker
# 2023-10-25 09:23:15,677 - distributed.nanny - WARNING - Restarting worker
# 2023-10-25 09:23:15,689 - distributed.nanny - WARNING - Restarting worker
# 2023-10-25 09:23:15,693 - distributed.nanny - WARNING - Restarting worker

# %%
print(str(type(ens._object._meta)))
print(str(ens._object.index))

print(ens._source._partitions)

print(ens._source.get_partition(0))
print(ens._source.get_partition(0).index)

# %%
print(str(len(ens)))
print(str(len(object_table)))

# %% [markdown]
# # Same as above but with head(1000)

# %%
# %%time
#%%memit

import light_curve as licu
import dask.dataframe as dd
import numpy as np
from tape import Ensemble, ColumnMapper

# In TAPE's (and LSST's) terminology, sources are individual detections,
# and objects are the underlying astrophysical objects.

# We load object table first, from the metadata file.
print("Loading object table...")
object_table = dd.read_csv(
    DATA_DIR / META_FILENAME,
    # Read data chunk by chunk, to avoid loading the whole file into memory.
    blocksize=100e6,
).head(1000)

# Then we load the sources:
print("Loading source tables...")
source_table = dd.read_csv(
    [DATA_DIR / filename for filename in LC_FILENAMES],
    blocksize=100e6,
).head(1000)

# Now we can make an Ensemble.
# To make parallel processing work we need to partition the data.
# After that, when we run analysis, TAPE will distribute the work:
# one partition per worker.
print("Building Ensemble...")
ens = Ensemble(
    n_workers=N_PROCESSORS,
)
ens.from_pandas(
    source_frame=source_table,
    object_frame=object_table,
    npartitions=1,
    column_mapper=ColumnMapper(
        id_col='object_id',
        time_col='mjd',
        flux_col='flux',
        err_col='flux_err',
        band_col='passband',
    ),
    # TODO: Doug, please put a comment here about the following line.
    sync_tables=False,
)

# Let's run some analysis!

print("Starting analysis...")
# First, let's select only Galactic objects, by cutting on hostgal_photoz.
print("First, filter by photoz")
ens = ens.query("hostgal_photoz < 1e-3", table="object")

# Second, let's select persistent sources, by cutting on the duration of the light curve.
print("Extract durations")
duration = ens.batch(
    lambda time, detected: np.ptp(time[np.asarray(detected, dtype=bool)]),
    ens._time_col, 'detected_bool',
    meta=('duration', 'float64'),
    use_map=False,
    compute=False,
)
print("Assign a column")
ens.assign(table="object", duration=duration)
print("Filter by duration")
ens = ens.query("duration > 366", table="object")

# Next, we use Otsu's method to split light curves into two groups:
# one with high flux, and one with low flux. Eclipsing binaries should have
# lower flux group smaller than the higher flux group, but having larger 
# variability. We use light-curve package to extract these features.
# (https://github.com/light-curve/light-curve-python)
# For simplicity, we only calculate these features for the i (3) band.
print("Extract Otsu features")
otsu_features = ens.batch(licu.OtsuSplit(), band_to_calc=3, use_map=False, compute=False)
print("Assign columns")
ens = ens.assign(
    table="object",
    otsu_lower_to_all_ratio=otsu_features['otsu_lower_to_all_ratio'],
    otsu_std_lower=otsu_features['otsu_std_lower'],
    otsu_std_upper=otsu_features['otsu_std_upper'],
)
print('Filter by Otsu features')
ens = ens.query(
    "otsu_lower_to_all_ratio < 0.1 and otsu_std_lower > otsu_std_upper",
    table="object",
)
print("Compute object table")
ens = ens.compute("object")

# %%
### Do the same, but with Pandas + joblib

The workflow is challenger here: we don't like to load all the light curves into memory (~20 GBi), so we have to manually jump between object table processing and source table processing.

NB: We also need `pyarrow.csv`, but only to read CSVs faster into pandas data-frames.

# %%
ens

# %% [markdown]
# # Example with the Refactored API

# %%
# %%time
#%%memit

import light_curve as licu
import dask.dataframe as dd
import numpy as np
from tape import Ensemble, ColumnMapper

# In TAPE's (and LSST's) terminology, sources are individual detections,
# and objects are the underlying astrophysical objects.

# We load object table first, from the metadata file.
print("Loading object table...")
object_table = dd.read_csv(
    DATA_DIR / META_FILENAME,
    # Read data chunk by chunk, to avoid loading the whole file into memory.
    blocksize=100e6,
)

# Then we load the sources:
print("Loading source tables...")
source_table = dd.read_csv(
    [DATA_DIR / filename for filename in LC_FILENAMES],
    blocksize=100e6,
)

# Now we can make an Ensemble.
# To make parallel processing work we need to partition the data.
# After that, when we run analysis, TAPE will distribute the work:
# one partition per worker.
print("Building Ensemble...")
ens = Ensemble(
    n_workers=N_PROCESSORS,
)
ens.from_dask_dataframe(
    source_frame=source_table,
    object_frame=object_table,
    npartitions=None,
    column_mapper=ColumnMapper(
        id_col='object_id',
        time_col='mjd',
        flux_col='flux',
        err_col='flux_err',
        band_col='passband',
    ),
    # TODO: Doug, please put a comment here about the following line.
    sync_tables=False,
)
# Out:
# Loading object table...
# Loading source tables...
# Building Ensemble...
# /Users/wilsonbb/Dropbox/lincc/tape/big_merge/tape/.conda/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 64959 instead
#   warnings.warn(
# Beginning setting index for frame: source
# set_dirty called for frame: source with value: False
# set_dirty called for frame: source with value: False
# Ending setting index for frame: source
# set_dirty called for frame: source with value: False
# Updating frame: source (is frame dirty: False)
# Updating frame: object (is frame dirty: False)
# Beginning setting index for frame: object
# Ending setting index for frame: object
# set_dirty called for frame: object with value: False
# Updating frame: object (is frame dirty: False)
# CPU times: user 4.79 s, sys: 1.26 s, total: 6.05 s
# Wall time: 28.2 s

# %%
# %%time
# Let's run some analysis!

print("Starting analysis...")
# First, let's select only Galactic objects, by cutting on hostgal_photoz.
print("First, filter by photoz")
filtered_objs = ens._object.query("hostgal_photoz < 1e-3")
# Out:
# Starting analysis...
# First, filter by photoz
# Beginning query for frame: object
# Ending query for frame: object
# set_dirty called for frame: object with value: False
# CPU times: user 44.7 ms, sys: 19.7 ms, total: 64.4 ms
# Wall time: 63.4 ms

# %%
# %%time
# Second, let's select persistent sources, by cutting on the duration of the light curve.
print("Extract durations")
duration = filtered_objs.update_ensemble().batch(
    lambda time, detected: np.ptp(time[np.asarray(detected, dtype=bool)]),
    ens._time_col, 'detected_bool',
    meta=('duration', 'float64'),
    use_map=False,
    compute=False,
)

ens.add_frame(duration, "duration")

print("duration table is of type: " + str(type(duration)))
print("Assign a column")
#ens._object.assign(duration=ens.select_frame("duration"))
print("Filter by duration")
filtered_durations = ens._object.query("duration > 366")

# Next, we use Otsu's method to split light curves into two groups:
# one with high flux, and one with low flux. Eclipsing binaries should have
# lower flux group smaller than the higher flux group, but having larger 
# variability. We use light-curve package to extract these features.
# (https://github.com/light-curve/light-curve-python)
# For simplicity, we only calculate these features for the i (3) band.
print("Extract Otsu features")
otsu_features = filtered_durations.update_ensemble().batch(licu.OtsuSplit(), band_to_calc=3, use_map=False, compute=False)
ens.add_frame(otsu_features, "otsu_freatures")

print("otsu_features table is of type:" + str(type(otsu_features)))

print("Assign columns")
ens = ens._object.assign(
    otsu_lower_to_all_ratio=otsu_features['otsu_lower_to_all_ratio'],
    otsu_std_lower=otsu_features['otsu_std_lower'],
    otsu_std_upper=otsu_features['otsu_std_upper'],
).update_ensemble()

print('Filter by Otsu features')
filtered_by_otsu = ens._object.query(
    "otsu_lower_to_all_ratio < 0.1 and otsu_std_lower > otsu_std_upper",
)
filtered_by_otsu.update_ensemble()

print("Compute object table")
ens.compute("object")
# Out:
# Extract durations
# Setting frame object as dirty
# set_dirty called for frame: object with value: True
# Updating frame: object (is frame dirty: True)
# _sync_tables started
# Syncing source table is started
# Syncing source table, index computed
# Setting frame source as dirty
# set_dirty called for frame: source with value: True
# Updating frame: source (is frame dirty: True)
# Syncing source table, partitions mapped
# Beginning persist for frame: source
# Ending persist for frame: source
# set_dirty called for frame: source with value: True
# 2023-10-25 09:10:10,004 - distributed.worker.memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 5.47 GiB -- Worker memory limit: 8.00 GiB
# Updating frame: source (is frame dirty: True)
# Syncing source table, frame persisted
# Syncing object table started
# Syncing object table index computed
# Updating frame: object (is frame dirty: False)
# Syncing object table partitions mapped
# Beginning persist for frame: object
# Ending persist for frame: object
# set_dirty called for frame: object with value: False
# Updating frame: object (is frame dirty: False)
# Syncing object table, frame persisted
# _sync_tables finished
# set_dirty called for frame: source with value: False
# set_dirty called for frame: object with value: False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:11
#
# File ~/Dropbox/lincc/tape/big_merge/tape/.conda/lib/python3.10/site-packages/tape/ensemble.py:116, in Ensemble.add_frame(self, frame, label)
#     114 frame.label = label
#     115 # Update the ensemble to track this labeled frame.
# --> 116 self.update_frame(frame)
#     117 return self
#
# File ~/Dropbox/lincc/tape/big_merge/tape/.conda/lib/python3.10/site-packages/tape/ensemble.py:158, in Ensemble.update_frame(self, frame)
#     155     print("Setting frame " + frame.label + " as dirty")
#     156     frame.set_dirty(True)
# --> 158 print("Updating frame: " + frame.label + " (is frame dirty: " + str(frame.is_dirty()) + ")")
#     159 # Ensure this frame is assigned to this Ensemble.
#     160 frame.ensemble = self
#
# AttributeError: 'Series' object has no attribute 'is_dirty'

# %% [markdown]
# ### Do the same but with Pandas + joblib

# %%
# %%time

import light_curve as licu
import numpy as np
import pandas as pd
import pyarrow
from joblib import Parallel, delayed

# Set number of threads to use when reading CSVs
pyarrow.set_cpu_count(N_PROCESSORS)
pyarrow.set_io_thread_count(N_PROCESSORS)

# First we load object table, from the metadata file.
print("Loading object table...")
object_table = pd.read_csv(DATA_DIR / META_FILENAME, engine='pyarrow', index_col='object_id')

print("Pre-filter object table")
# Before doing light-curve analysis we select only Galactic objects, by cutting on hostgal_photoz.
object_table = object_table[object_table['hostgal_photoz'] < 1e-3]


def read_source_table(filename):
    # We are going to read in parallel, so we set single thread 
    pyarrow.set_cpu_count(1)
    pyarrow.set_io_thread_count(1)
    return pd.read_csv(filename, engine='pyarrow', index_col='object_id')


def process_source_table(filename):
    source_table = read_source_table(filename)
    
    # Select sources for objects left
    source_table = source_table[source_table.index.isin(object_table.index)]
    
    # Select persistent sources, by cutting on the duration of the light curve.
    detections = source_table[source_table['detected_bool'].astype(bool)]
    # We need to group detections by object_id, to get light curves:
    durations = detections['mjd'].groupby(level=0).apply(np.ptp)
    
    # Then we filter the source table to keep only persistent sources:
    source_table = source_table.loc[durations[durations > 366].index]
    
    # Next, we use Otsu's method to split light curves into two groups:
    # one with high flux, and one with low flux. Eclipsing binaries should have
    # lower flux group significantly smaller than the higher flux group,
    # but having larger variability.
    # We use light-curve package to extract these features.
    # (https://github.com/light-curve/light-curve-python)
    # For simplicity, we only calculate these features for the i (3) band.
    
    otsu_split = licu.OtsuSplit()
    # i_band_sources = source_table[source_table['passband'] == 3]
    otsu_features = source_table[['mjd', 'flux', 'flux_err', 'passband']].groupby(level=0).apply(lambda row: pd.Series(
        otsu_split(
            np.asarray(row['mjd']),
            np.asarray(row['flux']),
            np.asarray(row['flux_err']),
            sorted=True,
            check=False,
        ),
        index=otsu_split.names,
    ))
    
    # And filter by Otsu features
    otsu_idx = (otsu_features['otsu_lower_to_all_ratio'] < 0.1) & (otsu_features['otsu_std_lower'] > otsu_features['otsu_std_upper'])
    
    return source_table.loc[otsu_idx.index[otsu_idx]]


# Running the main part of the analysis in parallel
print("Run analysis in parallel...")
source_tables = Parallel(n_jobs=N_PROCESSORS)(
    delayed(process_source_table)(DATA_DIR / filename) for filename in LC_FILENAMES
)
source_table = pd.concat(source_tables, ignore_index=False, sort=True)
object_table = object_table.loc[np.unique(source_table.index)]
object_table

# %% [markdown]
# # TODO
# ### Redo without having everything in-memory
# ### Add polars example

# %% [markdown]
# ### Do the same, but with Pandas+PyArrow w/ nested arrays for dataframes, and joblib for parallelism

# %%
# %%time

import light_curve as licu
import numpy as np
import pandas as pd
import pyarrow as pa
import pyarrow.csv as pacsv
from joblib import Parallel, delayed

# Read the data
# -------------

# First we load object table, from the metadata file.
print("Loading object table...")
object_table = pacsv.read_csv(
    DATA_DIR / META_FILENAME,
    # We'd like to load the whole file into a single partition
    read_options=pacsv.ReadOptions(block_size=(1<<31)-1),
)
object_table = pd.DataFrame(
    {
        col: pd.Series(
            object_table[col],
            dtype=pd.ArrowDtype(object_table[col].type),
            index=object_table['object_id'],
            copy=False,
        )
        for col in object_table.column_names if col != 'object_id'
    },
)

def read_source_table(filename):
    table = pacsv.read_csv(
        DATA_DIR / filename,
        # We'd like to have a partition per an original file
        read_options=pacsv.ReadOptions(block_size=(1<<31)-1),
    )
    return pd.DataFrame(
        {
            col: pd.Series(
                table[col],
                dtype=pd.ArrowDtype(table[col].type),
                index=table['object_id'],
                copy=False,
            )
            for col in table.column_names if col != 'object_id'
        },
    )

# source_tables = []
# for filename in LC_FILENAMES:
#     source_table = pa.csv.read_csv(
#         DATA_DIR / filename,
#         # We'd like to have a partition per an original file
#         read_options=pa.csv.ReadOptions(block_size=(1<<31)-1),
#     )
#     source_tables.append(pd.DataFrame(
#         {
#             col: pd.Series(
#                 source_table[col],
#                 dtype=pd.ArrowDtype(source_table[col].type),
#                 index=source_table['object_id'],
#                 copy=False,
#             )
#             for col in source_table.column_names if col != 'object_id'
#         },
#     ))
source_tables = Parallel(backend='threading', n_jobs=N_PROCESSORS)(
    delayed(read_source_table)(filename) for filename in LC_FILENAMES
)
source_table = pd.concat(source_tables, ignore_index=True, sort=False)


# Add sources to the object table
# -------------------------------

# First, let's do some sanity checks
print("Sanity checks...")
np.testing.assert_array_equal(
    object_table.index.values,
    np.unique(object_table.index.values),
    err_msg="Object table has duplicate indices or is not sorted.",
)
assert np.all(np.diff(source_table.index) >= 0), "Source table index must be sorted."

# We need an offsets array to know where each source light curve starts.
source_offsets = []
for table in source_tables:
    offset = np.nonzero(np.diff(table.index, prepend=-1, append=-1))[0]
    source_offsets.append(pa.array(offset))

# Update the object table with list-arrays built from the source table

print("Updating object table with list-arrays...")
for column in source_table.columns:
    list_arrays = []
    for table, offset in zip(source_tables, source_offsets):
        list_arrays.append(pa.ListArray.from_arrays(
            offset,
            pa.array(table[column]),
        ))
    chunked_array = pa.chunked_array(list_arrays)
    object_table[column] = pd.Series(
        chunked_array,
        dtype=pd.ArrowDtype(chunked_array.type),
        index=object_table.index,
    )
    
# Do analysis
# -----------

print("Starting analysis...")
# First, let's select only Galactic objects, by cutting on hostgal_photoz.
df = object_table[object_table['hostgal_photoz'] < 1e-3]

# Second, let's select persistent sources, by cutting on the duration of the light curve.
df['duration'] = df[['mjd', 'detected_bool']].apply(
    lambda row: np.ptp(row['mjd'][np.asarray(row['detected_bool'], dtype=bool)]),
    axis=1
)
df = df[df['duration'] > 366]

# Next, we use Otsu's method to split light curves into two groups:
# one with high flux, and one with low flux. Eclipsing binaries should have
# lower flux group significantly smaller than the higher flux group,
# but having larger variability.
# We use light-curve package to extract these features.
# (https://github.com/light-curve/light-curve-python)
# For simplicity, we only calculate these features for the i band.
def extract_band(*arrays, bands, band_to_calc):
    mask = np.asarray(bands) == band_to_calc
    return [np.asarray(arr)[mask] for arr in arrays]

otsu_split = licu.OtsuSplit()
otsu_features = df[['mjd', 'flux', 'flux_err', 'passband']].apply(
    lambda row: pd.Series(
        otsu_split(
            *extract_band(
                row['mjd'],
                row['flux'],
                row['flux_err'],
                bands=row['passband'],
                band_to_calc=3,  # i band
            ),
            sorted=True,
            check=False,
        ),
        index=otsu_split.names,
    ),
    axis=1
)

df = df[otsu_features['otsu_lower_to_all_ratio'] < 0.1]
df = df[otsu_features['otsu_std_lower'] > otsu_features['otsu_std_upper']]
df

# %%
import matplotlib.pyplot as plt

LSST_BANDS = 'ugrizy'

def plot(row):
    plt.figure()
    plt.title(f"Object {row.Index}, true class {row.true_target}")
    plt.xlabel('MJD')
    plt.ylabel('Flux, zp=27.5')
    for band_idx, band_name in enumerate(LSST_BANDS):
        mjd, flux, flux_err = extract_band(
            row.mjd,
            row.flux,
            row.flux_err,
            bands=row.passband,
            band_to_calc=band_idx,
        )
        color = f'C{band_idx}'
        plt.scatter(mjd, flux, c=color, label=band_name)
        plt.errorbar(mjd, flux, yerr=flux_err, ls='none', c=color)
        plt.legend()

# Random objects from the selected sample
for row in object_table[object_table['true_target'] == 16].sample(5, random_state=0).itertuples():
    plot(row)
    
# Random objects from the selected sample
for row in df.sample(5, random_state=0).itertuples():
    plot(row)
